# %% [markdown]
# ### Let's learn the Real Magic ! <br> One of the most important Libraries in Python for Data Science <br>
# # Pandas
#
# Pandas is an open-source Python Library providing high-performance data manipulation and analysis tool using its powerful data structures. The name Pandas is derived from the word Panel Data – an Econometrics from Multidimensional data.
#
# In 2008, developer Was McKinney started developing pandas when in need of high performance, flexible tool for analysis of data.
#
# Prior to Pandas, Python was majorly used for data munging and preparation. It had very little contribution towards data analysis. Pandas solved this problem. Using Pandas, we can accomplish five typical steps in the processing and analysis of data, regardless of the origin of data — load, prepare, manipulate, model, and analyze.
#
# Python with Pandas is used in a wide range of fields including academic and commercial domains including finance, economics, Statistics, analytics, etc.
# Key Features of Pandas
# ```
#     - Fast and efficient DataFrame object with default and customized indexing.
#     - Tools for loading data into in-memory data objects from different file formats.
#     - Data alignment and integrated handling of missing data.
#     - Reshaping and pivoting of date sets.
#     - Label-based slicing, indexing and subsetting of large data sets.
#     - Columns from a data structure can be deleted or inserted.
#     - Group by data for aggregation and transformations.
#     - High performance merging and joining of data.

# %%
import pandas as pd # Work directly - pandas comes pre installed with the anaconda package

# %%
import imblearn as imb  # does not exist in your system -> Install the library
# %pip install imblearn
# import imblearn as imb

# %%
print('Pandas Version : ' , pd.__version__)
# Out:
# Pandas Version :  1.5.0

# %% [markdown]
# ## Python Pandas - DataFrame
#
# A Data frame is a two-dimensional data structure, i.e., data is aligned in a tabular fashion in rows and columns.
# Features of DataFrame
#
#     Potentially columns are of different types
#     Size – Mutable
#     Labeled axes (rows and columns)
#     Can Perform Arithmetic operations on rows and columns

# %% [markdown]
# ### Structure
#
# Let us assume that we are creating a data frame with student’s data.
# Structure Table
#
# You can think of it as an SQL table or a spreadsheet data representation.
# pandas.DataFrame
#
# A pandas DataFrame can be created using the following constructor −
#
# pandas.DataFrame( data, index, columns, dtype, copy)

# %% [markdown]
# ### Create DataFrame
# A pandas DataFrame can be created using various inputs like −
#
#     Lists
#     dict
#     Series
#     Numpy ndarrays
#     Another DataFrame
#
# In the subsequent sections of this chapter, we will see how to create a DataFrame using these inputs.
# Create an Empty DataFrame
#
# A basic DataFrame, which can be created is an Empty Dataframe.

# %%
import pandas as pd

# 1D List
data = [10, 20, 30, 40]
df = pd.DataFrame(data, columns=['Values'])
print(df)
# Out:
#    Values
# 0      10
# 1      20
# 2      30
# 3      40

# %%
# 2D List
data_2d = [[1, 'Alice'], [2, 'Bob'], [3, 'Charlie']]
df_2d = pd.DataFrame(data_2d, columns=['ID', 'Name'])
print(df_2d)
# Out:
#    ID     Name
# 0   1    Alice
# 1   2      Bob
# 2   3  Charlie

# %%
# Dictionary
data_dict = {
    'ID': [1, 2, 3],
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35]
}
df_dict = pd.DataFrame(data_dict)
print(df_dict)
# Out:
#    ID     Name  Age
# 0   1    Alice   25
# 1   2      Bob   30
# 2   3  Charlie   35

# %% [markdown]
# ## Exercise
# Create a dictionary with the following data:
# ```
# 'Name': ['John', 'Emma', 'Sophia', 'Mike']
# 'Age': [28, 22, 25, 30]
# 'City': ['New York', 'Los Angeles', 'Chicago', 'Houston']
# ```
# Convert this dictionary into a Pandas DataFrame.

# %% [markdown]
# ## Import the dataset using Pandas

# %% [markdown]
# ### Download the data "listings.csv" from the below URL and put it in the notebook Directory
# Data  - https://www.kaggle.com/jojoker/singapore-airbnb/data

# %% [markdown]
# ### Reading Data into Pandas

# %% [markdown]
# ### https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html

# %% [markdown]
# pandas.read_csv(filepath_or_buffer: Union[str, pathlib.Path, IO[~AnyStr]],
#                 sep=',', delimiter=None, header='infer', names=None, index_col=None,
#                 usecols=None, squeeze=False, prefix=None, mangle_dupe_cols=True,
#                 dtype=None, engine=None, converters=None, true_values=None,
#                 false_values=None, skipinitialspace=False, skiprows=None, skipfooter=0,
#                 nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False,
#                 skip_blank_lines=True, parse_dates=False, infer_datetime_format=False,
#                 keep_date_col=False, date_parser=None, dayfirst=False, cache_dates=True,
#                 iterator=False, chunksize=None, compression='infer', thousands=None, decimal=b'.',
#                 lineterminator=None, quotechar='"', quoting=0, doublequote=True, escapechar=None,
#                 comment=None, encoding=None, dialect=None, error_bad_lines=True, warn_bad_lines=True,
#                 delim_whitespace=False, low_memory=True, memory_map=False, float_precision=None)

# %%
import pandas as pd
df = pd.read_csv('listings.csv') # Getting the data in the notebook

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# Peak at the dataset - first overview of the data
df.head() # by default shows top 5 rows
# Out:
#       id  \
# 0  49091
# 1  50646
# 2  56334
# 3  71609
# 4  71896
#
#                                   name  \
# 0    COZICOMFORT LONG TERM STAY ROOM 2
# 1      Pleasant Room along Bukit Timah
# 2                          COZICOMFORT
# 3  Ensuite Room (Room 1 & 2) near EXPO
# 4      B&B  Room 1 near Airport & EXPO
#
#    host_id  \
# 0   266763
# 1   227796
# 2   266763
# 3   367042
# 4   367042
#
#    host_name  \
# 0  Francesca
# 1    Sujatha
# 2  Francesca
# 3    Belinda
# 4    Belinda
#
#   neighbourhood_group  \
# 0        North Region
# 1      Central Region
# 2        North Region
# 3         East Region
# 4         East Region
#
#   neighbourhood  \
# 0     Woodlands
# 1   Bukit Timah
# 2     Woodlands
# 3      Tampines
# 4      Tampines
#
#    latitude  \
# 0   1.44255
# 1   1.33235
# 2   1.44246
# 3   1.34541
# 4   1.34567
#
#    longitude  \
# 0  103.79580
# 1  103.78521
# 2  103.79667
# 3  103.95712
# 4  103.95963
#
#       room_type  \
# 0  Private room
# ...

# %%
df.tail(10)
# Out:
#             id  \
# 7897  38092051
# 7898  38092142
# 7899  38094671
# 7900  38102097
# 7901  38104971
# 7902  38105126
# 7903  38108273
# 7904  38109336
# 7905  38110493
# 7906  38112762
#
#                                                     name  \
# 7897       New Small Room @Orchard/Somerset/Central Area
# 7898     Well connected 2 bedroom 2 bathroom apartment !
# 7899   SMALL ROOM FOR ONE @SOMERSET/ORCHARD/CENTRAL AREA
# 7900                                             环境优雅的公寓
# 7901                 2 PAX LOFT Close To Kent Ridge Park
# 7902  Loft 2 pax near Haw Par / Pasir Panjang. Free Wifi
# 7903                          3bedroom luxury at Orchard
# 7904     [ Farrer Park ] New City Fringe CBD Mins to MRT
# 7905           Cheap Master Room in Central of Singapore
# 7906  Amazing room with private bathroom walk to Orchard
#
#         host_id  \
# 7897  262337792
# 7898  223622603
# 7899  262337792
# 7900  286260560
# 7901  278109833
# 7902  278109833
# 7903  238891646
# ...

# %%
pd.set_option('display.max_rows',100)
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_colwidth', None)

# %%
#help(pd.set_option)

# %% [markdown]
# ### INFO COMMAND

# %% [markdown]
# #### Dataset Info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7907 entries, 0 to 7906
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              7907 non-null   int64
#  1   name                            7905 non-null   object
#  2   host_id                         7907 non-null   int64
#  3   host_name                       7907 non-null   object
#  4   neighbourhood_group             7907 non-null   object
#  5   neighbourhood                   7907 non-null   object
#  6   latitude                        7907 non-null   float64
#  7   longitude                       7907 non-null   float64
#  8   room_type                       7907 non-null   object
#  9   price                           7907 non-null   int64
#  10  minimum_nights                  7907 non-null   int64
#  11  number_of_reviews               7907 non-null   int64
# ...

# %% [markdown]
# - Observations from the Info Command -

# %% [raw]
# 1. Total Number of Rows - 7907
# 2. Total Number of columns - 16
# 3. Non Null values Count , Missing Values
# 4. Data Types
# 5. Memory Usage of the Dataset
# Add more

# %% [markdown]
# ### describe()

# %% [markdown]
# - Descriptive Data Statistics

# %%
df.describe(include = 'all')
# Out:
#                   id  \
# count   7.907000e+03
# unique           NaN
# top              NaN
# freq             NaN
# mean    2.338862e+07
# std     1.016416e+07
# min     4.909100e+04
# 25%     1.582180e+07
# 50%     2.470627e+07
# 75%     3.234850e+07
# max     3.811276e+07
#
#                                                      name  \
# count                                                7905
# unique                                               7457
# top     Luxury hostel with in-cabin locker - Single mixed
# freq                                                   13
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# ...

# %% [markdown]
# - Observations from the df.describe() function

# %% [raw]
# 1. Count
# 2. Mean
# 3. Standard Deviation
# 4. Minimum
# 5. 25th percentile,
# 6. 50th percentile,
# 7. 75th Percentile
# 8. Maximum
# 9. It only by default diaplays stats for numerical columns ( Float and Int )

# %% [markdown]
# ### .columns
#
# Let us now understand column selection, addition, and deletion through examples.

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group', 'neighbourhood', 'latitude',
#        'longitude', 'room_type', 'price', 'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count', 'availability_365'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=7907, step=1)

# %%
df.shape
# Out:
# (7907, 16)

# %% [markdown]
# ##### Column Selection
#
# We will understand this by selecting a column from the DataFrame.

# %%
df.columns # Attribute of the dataframe - characteristic property of the dataframe
# Out:
# Index(['id',
#        'name',
#        'host_id',
#        'host_name',
#        'neighbourhood_group',
#        'neighbourhood',
#        'latitude',
#        'longitude',
#        'room_type',
#        'price',
#        'minimum_nights',
#        'number_of_reviews',
#        'last_review',
#        'reviews_per_month',
#        'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %% [markdown]
# ## Access data in a dataframe

# %%
# access single column
# access multiple columns
# access single row
# access multiple rows
# access a cell

# %%
df.head(2)
# Out:
#       id  \
# 0  49091
# 1  50646
#
#                                 name  \
# 0  COZICOMFORT LONG TERM STAY ROOM 2
# 1    Pleasant Room along Bukit Timah
#
#    host_id  \
# 0   266763
# 1   227796
#
#    host_name  \
# 0  Francesca
# 1    Sujatha
#
#   neighbourhood_group  \
# 0        North Region
# 1      Central Region
#
#   neighbourhood  \
# 0     Woodlands
# 1   Bukit Timah
#
#    latitude  \
# 0   1.44255
# 1   1.33235
#
#    longitude  \
# 0  103.79580
# 1  103.78521
#
#       room_type  \
# 0  Private room
# 1  Private room
#
#    price  \
# 0     83
# 1     81
#
#    minimum_nights  \
# 0             180
# 1              90
#
#    number_of_reviews  \
# 0                  1
# 1                 18
#
#   last_review  \
# 0  2013-10-21
# 1  2014-12-26
#
#    reviews_per_month  \
# 0               0.01
# 1               0.28
#
#    calculated_host_listings_count  \
# 0                               2
# 1                               1
#
#    availability_365
# ...

# %%
df["name"] # single column
# Out:
# 0                        COZICOMFORT LONG TERM STAY ROOM 2
# 1                          Pleasant Room along Bukit Timah
# 2                                              COZICOMFORT
# 3                      Ensuite Room (Room 1 & 2) near EXPO
# 4                          B&B  Room 1 near Airport & EXPO
#                                ...
# 7902    Loft 2 pax near Haw Par / Pasir Panjang. Free Wifi
# 7903                            3bedroom luxury at Orchard
# 7904       [ Farrer Park ] New City Fringe CBD Mins to MRT
# 7905             Cheap Master Room in Central of Singapore
# 7906    Amazing room with private bathroom walk to Orchard
# Name: name, Length: 7907, dtype: object

# %%
df[["name" , "neighbourhood"]] # Multiple columns
# Out:
#                                                     name  \
# 0                      COZICOMFORT LONG TERM STAY ROOM 2
# 1                        Pleasant Room along Bukit Timah
# 2                                            COZICOMFORT
# 3                    Ensuite Room (Room 1 & 2) near EXPO
# 4                        B&B  Room 1 near Airport & EXPO
# ...                                                  ...
# 7902  Loft 2 pax near Haw Par / Pasir Panjang. Free Wifi
# 7903                          3bedroom luxury at Orchard
# 7904     [ Farrer Park ] New City Fringe CBD Mins to MRT
# 7905           Cheap Master Room in Central of Singapore
# 7906  Amazing room with private bathroom walk to Orchard
#
#      neighbourhood
# 0        Woodlands
# 1      Bukit Timah
# 2        Woodlands
# 3         Tampines
# 4         Tampines
# ...            ...
# 7902    Queenstown
# 7903       Tanglin
# 7904       Kallang
# 7905  River Valley
# 7906  River Valley
#
# [7907 rows x 2 columns]

# %%
df.loc[3]
# Out:
# id                                                              71609
# name                              Ensuite Room (Room 1 & 2) near EXPO
# host_id                                                        367042
# host_name                                                     Belinda
# neighbourhood_group                                       East Region
# neighbourhood                                                Tampines
# latitude                                                      1.34541
# longitude                                                   103.95712
# room_type                                                Private room
# price                                                             206
# minimum_nights                                                      1
# number_of_reviews                                                  14
# last_review                                                2019-08-11
# ...

# %%
df.loc[3:6] # end is inclusive
# Out:
#       id  \
# 3  71609
# 4  71896
# 5  71903
# 6  71907
#
#                                   name  \
# 3  Ensuite Room (Room 1 & 2) near EXPO
# 4      B&B  Room 1 near Airport & EXPO
# 5           Room 2-near Airport & EXPO
# 6     3rd level Jumbo room 5 near EXPO
#
#    host_id  \
# 3   367042
# 4   367042
# 5   367042
# 6   367042
#
#   host_name  \
# 3   Belinda
# 4   Belinda
# 5   Belinda
# 6   Belinda
#
#   neighbourhood_group  \
# 3         East Region
# 4         East Region
# 5         East Region
# 6         East Region
#
#   neighbourhood  \
# 3      Tampines
# 4      Tampines
# 5      Tampines
# 6      Tampines
#
#    latitude  \
# 3   1.34541
# 4   1.34567
# 5   1.34702
# 6   1.34348
#
#    longitude  \
# 3  103.95712
# 4  103.95963
# 5  103.96103
# 6  103.96337
#
#       room_type  \
# 3  Private room
# 4  Private room
# 5  Private room
# 6  Private room
#
#    price  \
# 3    206
# 4     94
# 5    104
# 6    208
#
#    minimum_nights  \
# 3               1
# ...

# %%
# row_index, column
df.loc[0, "price"]
# Out:
# 83

# %%
# df.loc[index_no, column_name] - Single Access

# %%
df.loc[[4,7,8] , ["name","host_name"]]
# Out:
#                                       name  \
# 4          B&B  Room 1 near Airport & EXPO
# 7   Long stay at The Breezy East "Leopard"
# 8  Long stay at The Breezy East "Plumeria"
#
#   host_name
# 4   Belinda
# 7    Bianca
# 8    Bianca

# %% [markdown]
# ## Exercise
#
# 1. Accessing the 14th column
# 2. Accessing the 12th and 15th column
# 3. Acessing the 999th Row
# 4. Accessing the rows from 320:420
# 5. Access the data in the cell of 5th column , second row
# 5. Access the 10,11,15 th listing prices, neighbourhood, neighbourhood_group

# %% [markdown]
# ## Drop Columns / Rows

# %%
# Methods and not functions
# object.method()

df.drop(["name", "host_name"], axis = 1 )
# Out:
#             id  \
# 0        49091
# 1        50646
# 2        56334
# 3        71609
# 4        71896
# ...        ...
# 7902  38105126
# 7903  38108273
# 7904  38109336
# 7905  38110493
# 7906  38112762
#
#         host_id  \
# 0        266763
# 1        227796
# 2        266763
# 3        367042
# 4        367042
# ...         ...
# 7902  278109833
# 7903  238891646
# 7904  281448565
# 7905  243835202
# 7906   28788520
#
#      neighbourhood_group  \
# 0           North Region
# 1         Central Region
# 2           North Region
# 3            East Region
# 4            East Region
# ...                  ...
# 7902      Central Region
# 7903      Central Region
# 7904      Central Region
# 7905      Central Region
# 7906      Central Region
#
#      neighbourhood  \
# 0        Woodlands
# 1      Bukit Timah
# 2        Woodlands
# 3         Tampines
# 4         Tampines
# ...            ...
# 7902    Queenstown
# 7903       Tanglin
# 7904       Kallang
# 7905  River Valley
# ...

# %%
df.head()
# Out:
#       id  \
# 0  49091
# 1  50646
# 2  56334
# 3  71609
# 4  71896
#
#                                   name  \
# 0    COZICOMFORT LONG TERM STAY ROOM 2
# 1      Pleasant Room along Bukit Timah
# 2                          COZICOMFORT
# 3  Ensuite Room (Room 1 & 2) near EXPO
# 4      B&B  Room 1 near Airport & EXPO
#
#    host_id  \
# 0   266763
# 1   227796
# 2   266763
# 3   367042
# 4   367042
#
#    host_name  \
# 0  Francesca
# 1    Sujatha
# 2  Francesca
# 3    Belinda
# 4    Belinda
#
#   neighbourhood_group  \
# 0        North Region
# 1      Central Region
# 2        North Region
# 3         East Region
# 4         East Region
#
#   neighbourhood  \
# 0     Woodlands
# 1   Bukit Timah
# 2     Woodlands
# 3      Tampines
# 4      Tampines
#
#    latitude  \
# 0   1.44255
# 1   1.33235
# 2   1.44246
# 3   1.34541
# 4   1.34567
#
#    longitude  \
# 0  103.79580
# 1  103.78521
# 2  103.79667
# 3  103.95712
# 4  103.95963
#
#       room_type  \
# 0  Private room
# ...

# %%
df.drop([3,5,9], axis = 0)

# %% [markdown]
# ## Renaming

# %%
df.head(3)
# Out:
#       ID                               NAME  HOST_ID  HOST_NAME NEIGHBOURHOOD_GROUP NEIGHBOURHOOD  \
# 0  49091  COZICOMFORT LONG TERM STAY ROOM 2   266763  Francesca        North Region     Woodlands
# 1  50646    Pleasant Room along Bukit Timah   227796    Sujatha      Central Region   Bukit Timah
# 2  56334                        COZICOMFORT   266763  Francesca        North Region     Woodlands
#
#    LATITUDE  LONGITUDE     ROOM_TYPE  PRICE  MINIMUM_NIGHTS  NUMBER_OF_REVIEWS LAST_REVIEW  \
# 0   1.44255  103.79580  Private room     83             180                  1  2013-10-21
# 1   1.33235  103.78521  Private room     81              90                 18  2014-12-26
# 2   1.44246  103.79667  Private room     69               6                 20  2015-10-01
#
#    REVIEWS_PER_MONTH  CALCULATED_HOST_LISTINGS_COUNT  AVAILABILITY_365
# 0               0.01                               2               365
# ...

# %%
# HOST_ID -> HOST_IDENTITY
# df.rename(columns = {"HOST_ID" : "HOST_IDENTITY", "HOST_NAME":"HOST"})

# %%
# df.rename({0 : "FIRST"}) # for renaming rows

# %%
# df.set_index("HOST_ID")

# %%
df.rename({"id" : "listing_id", "name" : "rename"} , axis = 1).head(5)
# Out:
#    listing_id  \
# 0       49091
# 1       50646
# 2       56334
# 3       71896
# 4       71907
#
#                               rename  \
# 0  COZICOMFORT LONG TERM STAY ROOM 2
# 1    Pleasant Room along Bukit Timah
# 2                        COZICOMFORT
# 3    B&B  Room 1 near Airport & EXPO
# 4   3rd level Jumbo room 5 near EXPO
#
#    host_id  \
# 0   266763
# 1   227796
# 2   266763
# 3   367042
# 4   367042
#
#    host_name  \
# 0  Francesca
# 1    Sujatha
# 2  Francesca
# 3    Belinda
# 4    Belinda
#
#   neighbourhood_group  \
# 0        North Region
# 1      Central Region
# 2        North Region
# 3         East Region
# 4         East Region
#
#   neighbourhood  \
# 0     Woodlands
# 1   Bukit Timah
# 2     Woodlands
# 3      Tampines
# 4      Tampines
#
#    latitude  \
# 0   1.44255
# 1   1.33235
# 2   1.44246
# 3   1.34567
# 4   1.34348
#
#    longitude  \
# 0  103.79580
# 1  103.78521
# 2  103.79667
# 3  103.95963
# 4  103.96337
#
#       room_type  \
# ...

# %%
df.rename({0 : "ZERO"}, axis = 0).head()
# Out:
#          id  \
# ZERO  49091
# 1     50646
# 2     56334
# 3     71896
# 4     71907
#
#                                    name  \
# ZERO  COZICOMFORT LONG TERM STAY ROOM 2
# 1       Pleasant Room along Bukit Timah
# 2                           COZICOMFORT
# 3       B&B  Room 1 near Airport & EXPO
# 4      3rd level Jumbo room 5 near EXPO
#
#       host_id  \
# ZERO   266763
# 1      227796
# 2      266763
# 3      367042
# 4      367042
#
#       host_name  \
# ZERO  Francesca
# 1       Sujatha
# 2     Francesca
# 3       Belinda
# 4       Belinda
#
#      neighbourhood_group  \
# ZERO        North Region
# 1         Central Region
# 2           North Region
# 3            East Region
# 4            East Region
#
#      neighbourhood  \
# ZERO     Woodlands
# 1      Bukit Timah
# 2        Woodlands
# 3         Tampines
# 4         Tampines
#
#       latitude  \
# ZERO   1.44255
# 1      1.33235
# 2      1.44246
# 3      1.34567
# 4      1.34348
#
#       longitude  \
# ...

# %% [markdown]
# If we want to rename all columns at once, this helpful snippet of code creates a dictionary
# with the old column names as keys and empty strings as values:

# %% [markdown]
# ##### Selection by integer location
#
# Rows can be selected by passing integer location to an iloc function.

# %% [markdown]
# ##### How do you find the unique values inside a pandas column

# %%
df.head(2)
# Out:
#       id  \
# 0  49091
# 1  50646
#
#                               name  \
# 0                         Puspendu
# 1  Pleasant Room along Bukit Timah
#
#    host_id  \
# 0   266763
# 1   227796
#
#    host_name  \
# 0  Francesca
# 1    Sujatha
#
#   neighbourhood_group  \
# 0        North Region
# 1      Central Region
#
#   neighbourhood  \
# 0     Woodlands
# 1   Bukit Timah
#
#    latitude  \
# 0   1.44255
# 1   1.33235
#
#    longitude  \
# 0  103.79580
# 1  103.78521
#
#       room_type  \
# 0  Private room
# 1  Private room
#
#     price  \
# 0  73.953
# 1  72.171
#
#    minimum_nights  \
# 0             180
# 1              90
#
#    number_of_reviews  \
# 0                  1
# 1                 18
#
#   last_review  \
# 0  2013-10-21
# 1  2014-12-26
#
#    reviews_per_month  \
# 0               0.01
# 1               0.28
#
#    calculated_host_listings_count  \
# 0                               2
# 1                               1
#
#    availability_365
# ...

# %%
# Numerical - .min() , .max(), .mean() , .sum()

# %%
# Categorical - nunique() , unique()

# %%
df["neighbourhood_group"].value_counts(normalize = True)#.round(4)*100
# Out:
# Central Region       0.798203
# West Region          0.068320
# East Region          0.063892
# North-East Region    0.043775
# North Region         0.025810
# Name: neighbourhood_group, dtype: float64

# %%
df['neighbourhood_group'].value_counts()
# Out:
# Central Region       6309
# West Region           540
# East Region           505
# North-East Region     346
# North Region          204
# Name: neighbourhood_group, dtype: int64

# %%
df['neighbourhood_group'].value_counts().index
# Out:
# Index(['Central Region',
#        'West Region',
#        'East Region',
#        'North-East Region',
#        'North Region'],
#       dtype='object')

# %%
df['neighbourhood_group'].value_counts().values
# Out:
# array([6309,  540,  505,  346,  204])

# %% [markdown]
# ### Finding the Minimum, Maximum, Sum, Average, and Count
# pandas comes with some built-in methods for commonly used descriptive statistics. In addition, Pandas offers variance (var), standard deviation (std), kurtosis (kurt), skewness (skew), standard error of the mean(sem), mode (mode), median (median), and a number of others.

# %%
# Calculate statistics
print('Maximum:', df['price'].max())
print('Minimum:', df['price'].min())
print('Mean:', df['price'].mean())
print('Sum:', df['price'].sum())
print('Count:', df['price'].count())

# Show counts
df.count()
# Out:
# Maximum: 9900.0
# Minimum: 0.0
# Mean: 167.6562870698381
# Sum: 1325155.2930000003
# Count: 7904
# id                                7904
# name                              7902
# host_id                           7904
# host_name                         7904
# neighbourhood_group               7904
# neighbourhood                     7904
# latitude                          7904
# longitude                         7904
# room_type                         7904
# price                             7904
# minimum_nights                    7904
# number_of_reviews                 7904
# last_review                       5146
# reviews_per_month                 5146
# calculated_host_listings_count    7904
# availability_365                  7904
# dtype: int64

# %%
df.describe().round(2).to_csv("data_description.csv")

# %% [markdown]
# ### .to_csv()

# %%
df.to_csv('exported_data.csv')

# %%
df1 = pd.read_csv('exported_data.csv')
df1.head()
# Out:
#    listing_id                                 name  host_id  host_name neighbourhood_group  \
# 0       49091    COZICOMFORT LONG TERM STAY ROOM 2   266763  Francesca        North Region
# 1       50646      Pleasant Room along Bukit Timah   227796    Sujatha      Central Region
# 2       50646  Ensuite Room (Room 1 & 2) near EXPO   367042    Belinda         East Region
# 3       71903           Room 2-near Airport & EXPO   367042    Belinda         East Region
# 4       71907     3rd level Jumbo room 5 near EXPO   367042    Belinda         East Region
#
#   neighbourhood  latitude  longitude     room_type  price  minimum_nights  number_of_reviews  \
# 0     Woodlands   1.44255  103.79580  Private room     83             180                  1
# 1   Bukit Timah   1.33235  103.78521  Private room     81              90                 18
# 2      Tampines   1.34541  103.95712  Private room    206               1                 14
# ...

# %%
df.to_csv('exported_data.csv', index = False)

# %%
df2=pd.read_csv('exported_data.csv')
df2.head()
# Out:
#       id                                 name  host_id  host_name  \
# 0  49091    COZICOMFORT LONG TERM STAY ROOM 2   266763  Francesca
# 1  50646      Pleasant Room along Bukit Timah   227796    Sujatha
# 2  56334                          COZICOMFORT   266763  Francesca
# 3  71609  Ensuite Room (Room 1 & 2) near EXPO   367042    Belinda
# 4  71896      B&B  Room 1 near Airport & EXPO   367042    Belinda
#
#   neighbourhood_group neighbourhood  latitude  longitude     room_type  price  \
# 0        North Region     Woodlands   1.44255  103.79580  Private room     83
# 1      Central Region   Bukit Timah   1.33235  103.78521  Private room     81
# 2        North Region     Woodlands   1.44246  103.79667  Private room     69
# 3         East Region      Tampines   1.34541  103.95712  Private room    206
# 4         East Region      Tampines   1.34567  103.95963  Private room     94
#
#    minimum_nights  number_of_reviews last_review  reviews_per_month  \
# ...
