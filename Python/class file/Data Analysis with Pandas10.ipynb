# %% [markdown]
# # Data Analysis Level 2
#
# ## **Filtering in Pandas DataFrame**
#
# Filtering is one of the core operations when working with Pandas DataFrames. It allows you to select rows based on specific conditions, making data analysis more efficient.
#
# **Filtering Rows Based on a Single Condition**
#
# You can filter rows by applying a condition to a column.
#
# ### **Steps:**
# 1. Use a boolean condition to filter rows.
# 2. Apply the condition using comparison operators like `==`, `!=`, `<`, `>`, `<=`, or `>=`.
# 3. Pass the condition to the DataFrame inside square brackets.

# %%
import pandas as pd
df = pd.read_csv("titanic3.csv")
df.head(5)
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000    0.0    0.0   24160  211.3375       B5        S    2    NaN
# 1   0.9167    1.0    2.0  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
# Filter passengers who are female
female_passengers = df[df['Sex'] == 'female']
female_passengers.head()

# %%
# Filter passengers who survived
survived_passengers = df[df['Survived'] == 1]
survived_passengers.head()

# %% [markdown]
# ## Exercise
# Filter passengers older than 50 years

# %% [markdown]
# ## **Filtering Rows Based on Multiple Conditions**
#
# You can combine multiple conditions when filtering rows in a Pandas DataFrame using:
#
# - **AND (`&`)**: Rows must meet **all conditions**.
# - **OR (`|`)**: Rows must meet **at least one condition**.
# - **NOT (`~`)**: Negates the condition (excludes rows meeting the condition).
#
# ## **Filtering with AND (`&`)**

# %%
filtered_df = df[(df['Sex'] == 'female') & (df['Age'] > 30)]
filtered_df[['Name', 'Sex', 'Age']].head()

# %% [markdown]
# ## **Filtering with OR (|)**

# %%
# Male passengers or those who survived
filtered_df = df[(df['Sex'] == 'male') | (df['Survived'] == 1)]
filtered_df[['Name', 'Sex', 'Survived']].head()

# %% [markdown]
# ## **Filtering with NOT (~)**

# %%
# Passengers who are not male
filtered_df = df[~(df['Sex'] == 'male')]
filtered_df[['Name', 'Sex']].head()

# %% [markdown]
# ## Combining Multiple Conditions

# %%
# Female passengers older than 30 who embarked at port 'C'
filtered_df = df[(df['Sex'] == 'female') & (df['Age'] > 30) & (df['Embarked'] == 'C')]
filtered_df[['Name', 'Sex', 'Age', 'Embarked']].head()

# %% [markdown]
# ## Exercise
# 1. Write a filter to find all passengers who Are male, and Have an Age greater than 40.<br>
# Display only the columns 'Name', 'Sex', and 'Age'.
# 2. Write a filter to find passengers who's Embarked at port "S", or Paid a Fare greater than 50. <br>
# Display only the columns 'Name', 'Embarked', and 'Fare'.
# 3. Write a filter to find all passengers who are not female. <br>
# Display only the columns 'Name', 'Sex', and 'Age'.
# 4. Write a filter to find passengers who meet all the following conditions:
#   - Are female,
#   - Have an Age greater than 35, and
#   - Paid a Fare less than 100.<br>
# Display only the columns 'Name', 'Sex', 'Age', and 'Fare'.
# 5. Write a filter to find passengers who:
#   - Survived, and
#   - Either:
#     - Embarked at port "C", or
#     - Paid a Fare greater than 50.<br>
# Display only the columns 'Name', 'Survived', 'Embarked', and 'Fare'.

# %% [markdown]
# # Replacing Values
# replace is a tool we use to replace values that is simple and yet has the powerful ability to accept regular expressions.

# %%
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000    0.0    0.0   24160  211.3375       B5        S    2    NaN
# 1   0.9167    1.0    2.0  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
df['sex'].replace({"female" : "F" , "male" : "M"})
# Out:
# 0         F
# 1         M
# 2         F
# 3         M
# 4         F
#        ...
# 1305      F
# 1306      M
# 1307      M
# 1308      M
# 1309    NaN
# Name: sex, Length: 1310, dtype: object

# %%
import numpy as np
df['cabin'].replace({np.nan : "-"})
# Out:
# 0            B5
# 1       C22 C26
# 2       C22 C26
# 3       C22 C26
# 4       C22 C26
#          ...
# 1305        NaN
# 1306        NaN
# 1307        NaN
# 1308        NaN
# 1309        NaN
# Name: cabin, Length: 1310, dtype: object

# %%
df['sex'] = df['sex'].replace({"male":"M" , "female" : "F"})

# %%
df['sex'] = df['sex'].replace(["M" , "F"] , ["MALE" , "FEMALE"]) # dict(zip([] , []))

# %%
df.rename({"pclass" : "Passenger Class"}, axis = 1, inplace = True) # index and columns

# %% [markdown]
# ## Exercise
# In the 'Embarked' column:
#   - Replace 'S' with 'Southampton'.
#   - Replace 'C' with 'Cherbourg'.
#   - Replace 'Q' with 'Queenstown'.<br>
# Display the updated DataFrame.

# %% [markdown]
# ## Pandas Groupby -
#
# The `groupby` function in Pandas is used to group data based on one or more columns. It allows you to perform aggregate operations, such as calculating sums, averages, counts, or other summary statistics for each group.
#
# ### 1 . Splitting criteria - single, multi level split
# ### 2 . Aggregation - takes numerical data and applies aggregation functions to them  - dict

# %%
df.head()
# Out:
#    Passenger Class  survived                                             name  \
# 0              1.0       1.0                    Allen, Miss. Elisabeth Walton
# 1              1.0       1.0                   Allison, Master. Hudson Trevor
# 2              1.0       0.0                     Allison, Miss. Helen Loraine
# 3              1.0       0.0             Allison, Mr. Hudson Joshua Creighton
# 4              1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#
#       sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0  female  29.0000    0.0    0.0   24160  211.3375       B5        S    2
# 1    male   0.9167    1.0    2.0  113781  151.5500  C22 C26        S   11
# 2  female   2.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN
# 3    male  30.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN
# 4  female  25.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN
#
#     body                        home.dest
# ...

# %%
# what is the average age by Gender ?
# Is there a significant difference between fare prices of survived individuals and not survived ?

# %%
df[df['sex']=='female']['age'].mean()
df[df['sex']=='male']['age'].mean()

# Splitting  - sex columns
# Consideration - age
# Aggregation Function - mean


# df.groupby(<SPLIT>).agg({<consideration> : <aggregation function>})

df.groupby("sex").agg({"age" : "mean"})
# Out:
#               age
# sex
# female  28.687071
# male    30.585233

# %%
df['survived'] = df['survived'].replace({0 : "No" , 1 : "Yes"})

# %%
df['count'] = 1
df.groupby(["sex","survived"]).agg({"primary" : "count"}) # Count - is a non null count
# Out:
#                  count
# sex    survived
# female No          127
#        Yes         339
# male   No          682
#        Yes         161

# %%
df.groupby(["sex" , "survived"]).agg({"age" : ["mean","max"] , "fare" : "mean"}).round(0).astype(int)
# Out:
#                  age     fare
#                 mean max mean
# sex    survived
# female No         25  63   22
#        Yes        30  76   55
# male   No         32  74   24
#        Yes        27  80   37

# %% [markdown]
# ## Exercise
#
# 1. Find the average cost of tickets by passenger class<br>
#   1.1 - By Gender, By Survival - find the min and maximum age of passengers
# 2. Find the passenger who paid the maximum cost for a ticket in both males and females
# 3. Find the average survival ratio by home destination
# 4. By gender, by survival - find average fare paid

# %% [markdown]
# ## Dropping Duplicate Rows
#
# In Pandas, duplicate rows can be removed easily using the `.drop_duplicates()` method. This is particularly useful for cleaning datasets.
#
# Use drop_duplicates, but be mindful of the parameters:

# %%
# Duplicate data should be allowed to exist

# %%
# Dataset - 10 Million users - 1st thing you will do ?

# Quality Check
# 1. Duplicates
# 2. Null values - usage statistics for 9 M - 7 M , 2M less
# 3. Data Cleaning - convert data to form it is in to the form you want it in
# 4. Analysis and usage for modelling

# %%
df = df.drop(1309)

# %%
df.drop("cabin", axis = 1, inplace = True)

# %%
len(df.drop_duplicates()) / len(df)
# Out:
# 1.0

# %%
df.loc[1309] = df.loc[1308]

# %%
len(df.drop_duplicates()) / len(df)
# Out:
# 0.999236641221374

# %%
len(df) - len(df.drop_duplicates())
# Out:
# 1

# %%
cols_list = list(df.columns)

# %%
cols_list.remove("count")

# %%
len(df.drop_duplicates()) / len(df)
# Out:
# 1.0

# %%
len(df.drop_duplicates()) / len(df)
# Out:
# 0.9992372234935164

# %%
df[ df.duplicated() ] # From Pranavi
# Out:
#       pclass  survived                name   sex   age  sibsp  parch  ticket  \
# 1309     3.0       0.0  Zimmerman, Mr. Leo  male  29.0    0.0    0.0  315082
#
#        fare cabin embarked boat  body home.dest
# 1309  7.875   NaN        S  NaN   NaN       NaN

# %%
# Primary Keys - composite keys - that can never be duplicated - Transaction ID
# Customer ID, Transaction ID , Date

# %%
df.drop(1309, inplace = True)

# %%
df.drop_duplicates(subset = ['survived', 'sex'])
# Out:
#    pclass  survived                                  name     sex      age  \
# 0     1.0       1.0         Allen, Miss. Elisabeth Walton  FEMALE  29.0000
# 1     1.0       1.0        Allison, Master. Hudson Trevor    MALE   0.9167
# 2     1.0       0.0          Allison, Miss. Helen Loraine  FEMALE   2.0000
# 3     1.0       0.0  Allison, Mr. Hudson Joshua Creighton    MALE  30.0000
#
#    sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0    0.0    0.0   24160  211.3375       B5        S    2    NaN
# 1    1.0    2.0  113781  151.5500  C22 C26        S   11    NaN
# 2    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
# 3    1.0    2.0  113781  151.5500  C22 C26        S  NaN  135.0
#
#                          home.dest survived_categorical  COUNT
# 0                     St Louis, MO                ALIVE      1
# 1  Montreal, PQ / Chesterville, ON                ALIVE      1
# 2  Montreal, PQ / Chesterville, ON                 DEAD      1
# ...

# %%
# Drop duplicates, show first two rows of output
df.drop_duplicates(inplace = True)

# %%
# count of Duplicate Values
len(df) - len(df.drop_duplicates())
# Out:
# 0

# %%
# Show number of rows
print("Number Of Rows In The Original DataFrame:", len(df))
print("Number Of Rows After Deduping:", len(df.drop_duplicates()))
# Out:
# Number Of Rows In The Original DataFrame: 1310
# Number Of Rows After Deduping: 1310

# %% [markdown]
# The solution didn’t actually drop any rows. The reason is because drop_duplicates defaults to only dropping rows that match perfectly across all columns. Under this condition, every row in our DataFrame, data frame, is actually unique. However, often we want to consider only a subset of columns to check for duplicate rows. We can accomplish this using the subset parameter:

# %%
# Drop duplicates
df.drop_duplicates(subset = ['cabin','sex','age'])
# Out:
#       pclass  survived                                             name  \
# 0        1.0       1.0                    Allen, Miss. Elisabeth Walton
# 1        1.0       1.0                   Allison, Master. Hudson Trevor
# 2        1.0       0.0                     Allison, Miss. Helen Loraine
# 3        1.0       0.0             Allison, Mr. Hudson Joshua Creighton
# 4        1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1263     3.0       0.0                van Billiard, Master. Walter John
# 1301     3.0       0.0                             Youseff, Mr. Gerious
# 1304     3.0       0.0                             Zabour, Miss. Hileni
# 1306     3.0       0.0                        Zakarian, Mr. Mapriededer
# 1309     NaN       NaN                                              NaN
#
#          sex      age  sibsp  parch    ticket      fare    cabin embarked  \
# ...

# %% [markdown]
# In this statement, we told drop_duplicates to only consider any two rows with the same value for Sex to be duplicates and to drop them. Now we are left with a DataFrame of only two rows: one man and one woman. You might be asking why drop_duplicates decided to keep these two rows instead of two different rows. The answer is that drop_duplicates defaults to keeping the first occurrence of a duplicated row and dropping the rest. We can control this behavior using the keep parameter:

# %%
# subset_cols_for_duplicates = list(df.columns).remove('timestamp')

# %%
# Drop duplicates
df.drop_duplicates(subset = subset_cols_for_duplicates, keep = 'last')
# Out:
#    pclass  survived                           name gender      age  sibsp  \
# 0     1.0       1.0  Allen, Miss. Elisabeth Walton      F  29.0000    0.0
# 1     1.0       1.0      AllisonMasterHudsonTrevor      M   0.9167    1.0
#
#    parch  ticket      fare    cabin embarked boat  body  \
# 0    0.0   24160  211.3375       B5        S    2   NaN
# 1    2.0  113781  151.5500  C22 C26        S   11   NaN
#
#                          home.dest    Fare
# 0                     St Louis, MO  169.07
# 1  Montreal, PQ / Chesterville, ON  121.24

# %% [markdown]
# **Note**: A related method is duplicated, which returns a boolean series denoting if a row is a duplicate or not. This is a good option if you don’t want to simply drop duplicates.

# %% [markdown]
# # Pivot table
# **What is pivot Table**<br>
# A pivot table is a table of statistics that summarizes the data of a more extensive table. In practical terms, a pivot table calculates a statistic on a breakdown of values. For the first column, it displays values as rows and for the second column as columns.

# %%
df = pd.read_csv("listings.csv")

df.head()
# Out:
#       id                                 name  host_id  host_name  \
# 0  49091    COZICOMFORT LONG TERM STAY ROOM 2   266763  Francesca
# 1  50646      Pleasant Room along Bukit Timah   227796    Sujatha
# 2  56334                          COZICOMFORT   266763  Francesca
# 3  71609  Ensuite Room (Room 1 & 2) near EXPO   367042    Belinda
# 4  71896      B&B  Room 1 near Airport & EXPO   367042    Belinda
#
#   neighbourhood_group neighbourhood  latitude  longitude     room_type  price  \
# 0        North Region     Woodlands   1.44255  103.79580  Private room     83
# 1      Central Region   Bukit Timah   1.33235  103.78521  Private room     81
# 2        North Region     Woodlands   1.44246  103.79667  Private room     69
# 3         East Region      Tampines   1.34541  103.95712  Private room    206
# 4         East Region      Tampines   1.34567  103.95963  Private room     94
#
#    minimum_nights  number_of_reviews last_review  reviews_per_month  \
# ...

# %%
# df.groupby(['neighbourhood_group', 'room_type']).agg({"price" : "mean"})
pd.set_option("display.max_columns", 1000)
df.pivot_table(index = "neighbourhood_group" , columns = "room_type",
              values = "price" , aggfunc = "mean")
# Out:
# room_type            Entire home/apt  Private room  Shared room
# neighbourhood_group
# Central Region            224.581862    114.380117    59.198276
# East Region               209.358779    117.234973   187.090909
# North Region              188.433962     81.992958   107.666667
# North-East Region         191.671875     79.878676    55.000000
# West Region               334.178082    117.825397   106.125000

# %%
df.pivot_table(index="embarked", columns="survived", values="fare", aggfunc='mean')
# Out:
# survived        0.0        1.0
# embarked
# C         40.255592  80.000807
# Q         11.615349  13.833998
# S         21.546160  39.183470

# %% [markdown]
# **Can I calculate multiple statistics at the same time?** <br>
#
# The argument aggfunc of pivot_table function takes a list of functions. Let’s try it with sum and mean.

# %%
df.pivot_table(index="embarked", columns="survived", values="fare", aggfunc=['sum','mean'])
# Out:
#                  sum                   mean
# survived         0.0         1.0        0.0        1.0
# embarked
# C          4830.6711  12000.1211  40.255592  80.000807
# Q           917.6126    608.6959  11.615349  13.833998
# S         13121.6114  11911.7748  21.546160  39.183470

# %% [markdown]
# ## Exercise
# Create a pivot table to calculate the survival rate ('Survived') for each combination of:
#   - 'Pclass'
#   - 'Sex'
#   - 'Embarked'<br>
# Display the survival rate as percentages.

# %% [markdown]
# # Looping Over a Column

# %%
for i in range(len(df)):

    df.loc[i,'price'] = df.loc[i,'price']*1.1

# %%
# Price > 80 ignore, <80 - add 10 price units

for i in range(len(df)): # df.index
    price_val = df.loc[i,'price']

    if price_val < 80:
        df.loc[i,'price'] = df.loc[i,'price'] + 10

# %%
df.drop(1309, inplace = True)

# %%
df = pd.read_csv("titanic3.csv")
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000    0.0    0.0   24160  211.3375       B5        S    2    NaN
# 1   0.9167    1.0    2.0  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
# %%timeit

for i in range(len(df['name'])):

    name = df.loc[i,'name']
    try:
        if ("Mr." in name) or ("Mrs." in name):
            df.loc[i,'Marital_Status'] = "Married"
        elif ("Master." in name) or ("Miss." in name):
            df.loc[i,'Marital_Status'] = "Single"
        else:
            df.loc[i,'Marital_Status'] = "Unknown"
    except:
        pass
# Out:
# 396 ms ± 7.53 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
def marital_status_finder(name):

    if ("Mr." in name) or ("Mrs." in name):
        return "Married"
    elif ("Master." in name) or ("Miss." in name):
        return "Single"
    else:
        return "Unknown"

# %%
df.drop(1309, inplace = True)

# %%
# %%timeit
df['name'].apply(marital_status_finder)
# Out:
# 255 µs ± 7.05 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# # Applying a Function Over All Elements in a Column
# apply is a great way to do data cleaning and wrangling. It is common to write a function to perform some useful operation (separate first and last names, convert strings
# to floats, etc.) and then map that function to every element in a column

# %%
def marital_status(name):
    name = name.lower()
    name = " "+name
    if (" mr " in name) or (" mr." in name) or ("mrs." in name):
        return "Married"
    elif ("master." in name) or ("miss." in name):
        return "Single"
    else:
        return "Unknown"

# %%
df['name'].apply(marital_status)
# Out:
# 0        Single
# 1        Single
# 2        Single
# 3       Married
# 4       Married
#          ...
# 1304     Single
# 1305     Single
# 1306    Married
# 1307    Married
# 1308    Married
# Name: name, Length: 1309, dtype: object

# %%
# %%timeit
df['Marital_Status'] = df['name'].apply(marital_status)
# Out:
# 335 µs ± 7.51 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
dataframe=pd.read_csv("data/titanic3.csv")
#dataframe.info()

# Create function
def uppercase(x):
    return str(x).upper()

# Apply function, show two rows
dataframe['sex'].apply(uppercase)

# %%
dataframe['sex'] = dataframe['sex'].apply(uppercase)

# %%
dataframe.head(2)
# Out:
#    pclass  survived                            name     sex      age  sibsp  \
# 0     1.0       1.0   Allen, Miss. Elisabeth Walton  FEMALE  29.0000    0.0
# 1     1.0       1.0  Allison, Master. Hudson Trevor    MALE   0.9167    1.0
#
#    parch  ticket      fare    cabin embarked boat  body  \
# 0    0.0   24160  211.3375       B5        S    2   NaN
# 1    2.0  113781  151.5500  C22 C26        S   11   NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON

# %%
dataframe.loc[1,'sex']
# Out:
# 'MALE'

# %%
# %%timeit

for i in range(len(dataframe)):
    dataframe.loc[i,'sex'] = dataframe.loc[i,'sex'].upper()
# Out:
# 616 ms ± 43.2 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
dataframe['sex'].apply(uppercase)
# Out:
# 606 µs ± 21 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %% [markdown]
# # Applying a Function to Groups
# apply is particularly useful when you want to
# apply a function to groups. By combining groupby and apply we can calculate custom statistics or apply any function to each group separately.

# %%
# Lambda Function -
# I'm not going to define the name and other details of the function
# Create and use it on the fly

# %%
def adder(a,b ):
    return a+b

# %%
lambda a,b : a+b if a<0 else a-b # Simple, anonymous, one liner functions to use on the fly

# %%
f(-1, 5)
# Out:
# 4

# %%
f(10,5)
# Out:
# 5

# %%
# dataframe=pd.read_csv("data/titanic3.csv")

# Group rows, apply function to groups
# df.groupby("sex").agg({"age":"mean"})

df.groupby('sex').apply(lambda x: x['age'].mean())
# Out:
# sex
# female    28.687071
# male      30.585233
# dtype: float64

# %%
df.groupby('sex').apply(lambda x: x.count()) # Count - adds 1 for EXISTING value, 0 for Missing values
# Out:
#         pclass  survived  name  sex  age  sibsp  parch  ticket  fare  cabin  \
# sex
# female     466       466   466  466  388    466    466     466   466    141
# male       843       843   843  843  658    843    843     843   842    154
#
#         embarked  boat  body  home.dest  Marital_Status
# sex
# female       464   319     8        288             466
# male         843   167   113        457             843

# %% [markdown]
# # Concatenating DataFrames
# The informal definition
# of concatenate is to glue two objects together. In the solution we glued together two small DataFrames using the axis parameter to indicate whether we wanted to stack
# the two DataFrames on top of each other or place them side by side.

# %%
# file - .csv (.read_csv , .read_excel) file - get the dataframe
# data is generated by code - Python datatype - dict, list, tuple set etc.

# %%
# Create DataFrame
data_a = {'id': ['1', '2', '3'],
          'first': ['Alex', 'Amy', 'Allen'],
          'last': ['Anderson', 'Ackerman', 'Ali']}
dataframe_a = pd.DataFrame(data_a, columns = ['id', 'first', 'last'])

# Create DataFrame
data_b = {'id': ['4', '5', '6'],
          'first': ['Billy', 'Brian', 'Bran'],
          'last': ['Bonder', 'Black', 'Balwner']}
dataframe_b = pd.DataFrame(data_b, columns = ['id', 'first', 'last'])

# %%
dataframe_a
# Out:
#   id  first      last
# 0  1   Alex  Anderson
# 1  2    Amy  Ackerman
# 2  3  Allen       Ali

# %%
dataframe_b
# Out:
#   id  first     last
# 0  4  Billy   Bonder
# 1  5  Brian    Black
# 2  6   Bran  Balwner

# %%
concat_df = pd.concat([dataframe_a , dataframe_b.drop(columns = ["last"])], axis = 0).reset_index(drop = True) # default - Vertical
concat_df
# Out:
#   id  first      last
# 0  1   Alex  Anderson
# 1  2    Amy  Ackerman
# 2  3  Allen       Ali
# 3  4  Billy       NaN
# 4  5  Brian       NaN
# 5  6   Bran       NaN

# %%
# Create row
row = pd.Series([10,  'Chillon','Chris'], index=['id', 'last','first'])
# Append row
dataframe_a.append(row, ignore_index=True)
# Out:
#    id  first      last
# 0   1   Alex  Anderson
# 1   2    Amy  Ackerman
# 2   3  Allen       Ali
# 3  10  Chris   Chillon

# %%
# temp = pd.read_csv("listings.csv")
# pd.to_datetime(temp['last_review'])

# %% [markdown]
# # Merging DataFrames
# Oftentimes, the data we need to use is complex; it doesn’t always come in one piece. Instead in the real world, we’re usually faced with disparate datasets, from multiple database queries or files. To get all that data into one place, we can load each data query or data file into pandas as individual DataFrames and then merge them
# together into a single DataFrame.
#
# This process might be familiar to anyone who has used SQL, a popular language for doing merging operations (called joins). While the exact parameters used by pandas
# will be different, they follow the same general patterns used by other software lan‐
# guages and tools.
#
# There are three aspects to specify with any merge operation. First, we have to specify the two DataFrames we want to merge together. In the solution we named them dataframe_employees and dataframe_sales. Second, we have to specify the name(s) of the columns to merge on—that is, the columns whose values are shared between the
# two DataFrames. For example, in our solution both DataFrames have a column named employee_id. To merge the two DataFrames we will match up the values in each DataFrame’s employee_id column with each other. If these two columns use the same name, we can use the on parameter. However, if they have different names we
# can use left_on and right_on.
#
# What is the left and right DataFrame? The simple answer is that the left DataFrame is the first one we specified in merge and the right DataFrame is the second one. This
# language comes up again in the next sets of parameters we will need.
#
# The last aspect, and most difficult for some people to grasp, is the type of merge operation we want to conduct. This is specified by the how parameter. merge supports the four main types of joins:
#
# **Inner Join**: Return only the rows that match in both DataFrames (e.g., return any row with an employee_id value appearing in both dataframe_employees and data
# frame_sales).
#
#
# **Outer Join**: Return all rows in both DataFrames. If a row exists in one DataFrame but not in the other DataFrame, fill NaN values for the missing values (e.g., return all rows in both employee_id and dataframe_sales).
#
# **Left Join**: Return all rows from the left DataFrame but only rows from the right DataFrame that matched with the left DataFrame. Fill NaN values for the missing values (e.g., return all rows from dataframe_employees but only rows from data frame_sales that have a value for employee_id that appears in dataframe_employees).
#
# **Right Join**: Return all rows from the right DataFrame but only rows from the left DataFrame that matched with the right DataFrame. Fill NaN values for the missing values (e.g., return all rows from dataframe_sales but only rows from data frame_employees that have a value for employee_id that appears in dataframe_sales).

# %%
# MERGE

# Ideas we need to keep in mind -

# How many tables can we merge at once ?
# We need to provide the column on the basis of which we merge -
# If the column names are different in the two tables - then we have to provide the 2 column names as well
# The joining criteria - how = inner, outer, left, right

# %%
# Create DataFrame
employee_data = {'employee_id': ['1', '2', '3', '4'],
                 'name': ['Amy Jones', 'Allen Keys', 'Alice Bees','Tim Horton']}
dataframe_employees = pd.DataFrame(employee_data, columns = ['employee_id','name'])

# Create DataFrame
sales_data = {'emp_id': ['3', '4', '5', '6'],
              'total_sales': [23456, 2512, 2345, 1455]}
dataframe_sales = pd.DataFrame(sales_data, columns = ['emp_id','total_sales'])

# %%
dataframe_employees
# Out:
#   employee_id        name
# 0           1   Amy Jones
# 1           2  Allen Keys
# 2           3  Alice Bees
# 3           4  Tim Horton

# %%
dataframe_sales
# Out:
#   emp_id  total_sales
# 0      3        23456
# 1      4         2512
# 2      5         2345
# 3      6         1455

# %%
pd.merge(dataframe_employees ,dataframe_sales,
         left_on = "employee_id" , # same column - on = "emp_id"
         right_on = "emp_id",
         how = "outer" ) # left, right, inner, outer
# Out:
#   employee_id        name emp_id  total_sales
# 0           1   Amy Jones    NaN          NaN
# 1           2  Allen Keys    NaN          NaN
# 2           3  Alice Bees      3      23456.0
# 3           4  Tim Horton      4       2512.0
# 4         NaN         NaN      5       2345.0
# 5         NaN         NaN      6       1455.0

# %%
# merged_df[pd.notnull(merged_df['total_sales'])]

# %% [raw]
# ## Exercise
#
# ### **Dataset Setup**
#
# Use the following code to create sample DataFrames for the exercises:
#
# ```python
# # DataFrame 1: Titanic Passenger Information (Sample)
# data1 = {
#     'PassengerId': [1, 2, 3, 4],
#     'Name': ['John', 'Alice', 'Bob', 'Mary'],
#     'Pclass': [1, 2, 3, 1]
# }
# df1 = pd.DataFrame(data1)
#
# # DataFrame 2: Survival Information
# data2 = {
#     'PassengerId': [1, 2, 3, 4],
#     'Survived': [1, 0, 1, 1],
#     'Age': [22, 28, 34, 45]
# }
# df2 = pd.DataFrame(data2)
#
# # DataFrame 3: Embarkation Information
# data3 = {
#     'PassengerId': [3, 4, 5, 6],
#     'Embarked': ['S', 'C', 'Q', 'S'],
#     'Fare': [7.25, 71.83, 8.05, 15.5]
# }
# df3 = pd.DataFrame(data3)

# %% [markdown]
# 1. Merge df1 and df2 on 'PassengerId' using an inner join.<br>
# Display the resulting DataFrame.
# 2. Merge df2 and df3 on 'PassengerId' using a left join.<br>
# Display the resulting DataFrame.
# 3. Concatenate df1 and df3 vertically (along rows).<br>
# Reset the index after concatenation.
# Display the resulting DataFrame.
# 4. Concatenate df1 and df2 horizontally (along columns).<br>
# Display the resulting DataFrame.
# 5. Merge all three DataFrames (df1, df2, and df3) into a single DataFrame:
#   - Use an outer join on 'PassengerId'.
#   - Display the resulting DataFrame.
